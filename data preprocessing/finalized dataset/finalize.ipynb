# %%
import pandas as pd

# %%
generated = pd.read_csv(r'C:\Users\LENOVO\Desktop\Lectures 5\Internship\Works\Task 2.1\Health-insureance\data preprocessing\generated data preprocessing\generated data.csv')
qna = pd.read_csv(r'C:\Users\LENOVO\Desktop\Lectures 5\Internship\Works\Task 2.1\Health-insureance\data preprocessing\Q&As and FAQs\health_insurance_qna.csv')

# %%
generated
# Out:
#                                                question  \
# 0     What is the difference between an in-network a...
# 1     What is a deductible and how does it work in m...
# 2     What should I consider when choosing a health ...
# 3     Are pre-existing conditions covered under heal...
# 4     What is the importance of understanding your h...
# ...                                                 ...
# 2795  How is the cost of health insurance determined...
# 2796  How is the cost of health insurance determined...
# 2797  How is the cost of health insurance determined...
# 2798  How is the cost of health insurance determined...
# 2799  How is the cost of health insurance determined...
#
#                                                  answer
# 0     In-network providers are healthcare profession...
# 1     A deductible is the amount you pay out-of-pock...
# 2     When choosing a health insurance plan, conside...
# 3     Yes, many health insurance plans provide cover...
# ...

# %%
qna
# Out:
#                                                question  \
# 0                      Why do we need health insurance?
# 1                        How do I get health insurance?
# 2                             What is health insurance?
# 3                    Why should I buy health insurance?
# 4     How will health insurance pay for my emergency...
# ...                                                 ...
# 1209          why do i need critical illness insurance?
# 1210                       is life insurance essential?
# 1211               is disability insurance a good idea?
# 1212           when can you enroll in health insurance?
# 1213              who can be covered by life insurance?
#
#                                                  answer
# 0     As medical care advances and treatments increa...
# 1     Most people get health insurance through their...
# 2     Health insurance is an insurance product that ...
# 3     You should purchase health insurance so that y...
# ...

# %%
df = pd.concat([generated, qna], ignore_index=True)

# %%
df
# Out:
#                                                question  \
# 0     What is the difference between an in-network a...
# 1     What is a deductible and how does it work in m...
# 2     What should I consider when choosing a health ...
# 3     Are pre-existing conditions covered under heal...
# 4     What is the importance of understanding your h...
# ...                                                 ...
# 4009          why do i need critical illness insurance?
# 4010                       is life insurance essential?
# 4011               is disability insurance a good idea?
# 4012           when can you enroll in health insurance?
# 4013              who can be covered by life insurance?
#
#                                                  answer
# 0     In-network providers are healthcare profession...
# 1     A deductible is the amount you pay out-of-pock...
# 2     When choosing a health insurance plan, conside...
# 3     Yes, many health insurance plans provide cover...
# ...

# %%
df.to_csv("finalized_health_insurance_qna.csv", index=False)
